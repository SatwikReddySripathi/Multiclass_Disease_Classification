# %%
# !pip install torchmetrics
# Out:
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.5.0+cu121)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (0.11.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)

# %%
# !pip install ray[tune]
# Out:
# Requirement already satisfied: ray[tune] in /usr/local/lib/python3.10/dist-packages (2.39.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (3.16.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (1.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (4.25.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (6.0.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (1.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (2.2.2)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (17.0.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from ray[tune]) (2024.10.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from pyarrow>=6.0.1->ray[tune]) (1.26.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[tune]) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[tune]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[tune]) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[tune]) (0.21.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[tune]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[tune]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[tune]) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->ray[tune]) (1.16.0)

# %%
import os
import io
import ast
import torch
import pickle
import numpy as np
from PIL import Image

import ray
from ray import tune

import torch.nn as nn
import torch.optim as optim
from torchvision import models
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import random_split, DataLoader, TensorDataset

from torch.utils.tensorboard import SummaryWriter
from torchmetrics.classification import MultilabelPrecision, MultilabelRecall, MultilabelF1Score

# %%
ray.shutdown()
ray.init(ignore_reinit_error=True)
# Out:
# 2024-11-14 21:51:59,272	INFO worker.py:1819 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.10.12', ray_version='2.39.0', ray_commit='5a6c33536df3f6ed5e987a169b82739bb7e3d80e')

# %%
print(ray.cluster_resources())
# Out:
# {'CPU': 2.0, 'object_store_memory': 4000217088.0, 'node:172.28.0.12': 1.0, 'memory': 8000434176.0, 'node:__internal_head__': 1.0}

# %%
@ray.remote
def simple_task(x):
    import time
    time.sleep(2)  # Simulate work
    return x * x

# Run tasks in parallel
results = ray.get([simple_task.remote(i) for i in range(10)])
print(results)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
config = {
    "num_epochs": tune.randint(5, 20),
    "batch_size": tune.choice([16, 32, 64]),
    "learning_rate": tune.loguniform(1e-6, 1e-3),
    "demographics_fc_size": tune.choice([32, 64, 128]),
    "file_path": "/content/preprocessed_dummy_data.pkl",
    "train_percent": 0.7,
    "val_percent": 0.1,
    "num_demographics": 3,
    "num_classes": 15,
}

# %%
def load_data(original_data_pickle, batch_size, train_percent, val_percent, target_size=(224, 224)):
    images = []
    demographics = []
    labels= []

    resize_transform = transforms.Compose([
        transforms.Resize(target_size),
        transforms.ToTensor()
    ])

    with open(original_data_pickle, 'rb') as f:
        data = pickle.load(f)

    for item in data.values():

      """
      The image data we get would be in bytes. We need to open it and convert it to grey scale and then resize. Recheck it. What are we doing with resizing before then?
      """
      image_data = item['image_data']
      image = Image.open(io.BytesIO(image_data)).convert('L')
      image = resize_transform(image)  # Resizing and converting to tensor with shape (1, H, W) --> got an error without it

      label= item['image_label']
      label = ast.literal_eval(label)
      label = np.array(label, dtype=int)

      age = torch.tensor([item['age']], dtype=torch.float32)
      gender = torch.tensor(item['gender'], dtype=torch.float32)

      images.append(image)
      demographics.append(torch.cat([age, gender]))
      labels.append(label)

    """
    Stacking images and demographics.
    images Shape: (num_samples, channels, height, width)
    demographics Shape: (num_samples, num_features)
    """
    images = torch.stack(images)
    demographics = torch.stack(demographics)
    labels = torch.stack([torch.tensor(label, dtype=torch.long) for label in labels])
    #labels = torch.tensor(labels, dtype= torch.long)

    dataset = TensorDataset(images, demographics, labels)

    train_size = int(train_percent * len(dataset))
    val_size = int(val_percent * len(dataset))
    test_size = len(dataset) - train_size - val_size

    train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    print(f"Training samples: {len(train_dataset)}, Validation samples: {len(val_dataset)}, Test samples: {len(test_dataset)}")

    return train_loader, val_loader, test_loader

# %%
train_loader, val_loader, test_loader= load_data(config['file_path'], 32, 0.7, 0.1)
print(train_loader)
# Out:
# Training samples: 35, Validation samples: 5, Test samples: 10
# <torch.utils.data.dataloader.DataLoader object at 0x7c3d1de094b0>

# %%
class CustomResNet18(nn.Module):
    def __init__(self, demographic_fc_size, num_demographics, num_classes=15):
        super(CustomResNet18, self).__init__()

        self.resnet = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

        # Modifying the first convolutional layer to accept grayscale images (1 channel) --> generally ResNet expects 3 channels
        #for RGB
        self.resnet.conv1 = nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)

        # Removing the final fully connected layer in ResNet
        self.resnet = nn.Sequential(*list(self.resnet.children())[:-1])

        # this fc processes the demographics (age + gender)
        self.demographics_fc = nn.Sequential(
            nn.Linear(num_demographics, demographic_fc_size),
            nn.ReLU(),
            nn.Dropout(0.5)
        )

        self.fc = nn.Linear(512 + demographic_fc_size, num_classes)  # 512 from ResNet(it's how resnet is), 32 from demographics_fc, can make it 64?

    def forward(self, images, demographics):
        x = self.resnet(images)  # Passing images through the modified ResNet (without its last layer)
        x = x.view(x.size(0), -1)  # Flattening the ResNet output

        demographics_features = self.demographics_fc(demographics)
        x = torch.cat((x, demographics_features), dim=1)

        #print("Shape after concatenating demographics:", x.shape)

        x = self.fc(x)
        #print("Output shape before returning:", x.shape)

        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
writer = SummaryWriter("runs/CustomResNet18_experiment")

def freeze_unfreeze_layers(model, freeze=True, layers_to_train=["layer4", "fc"]):
    for name, param in model.named_parameters():
        if any(layer in name for layer in layers_to_train):
            param.requires_grad = not freeze
        else:
            param.requires_grad = freeze

@ray.remote
def train_model(train_loader, val_loader, model, criterion, optimizer, num_epochs= 10):

  model.train()

  best_val_accuracy = 0
  for epoch in range(num_epochs):
    running_loss = 0.0
    for inputs, demographics, labels in train_loader:
      inputs, demographics, labels = inputs.to(device), demographics.to(device), labels.to(device)

      # Repeating grayscale images to make them 3 channels - this is not needed now since I changed the ResNet to accept grayscale,
      #in-general ResNet expects RGB images ig

      #inputs = inputs.repeat(1, 3, 1, 1)

      optimizer.zero_grad()

      outputs = model(inputs, demographics)
      loss = criterion(outputs, labels.float())

      loss.backward()
      optimizer.step()

      running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)
    #writer.add_scalar("Loss/Train", avg_train_loss, epoch)


    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
      for inputs, demographics, labels in val_loader:
        inputs, demographics, labels = inputs.to(device), demographics.to(device), labels.to(device)
        outputs = model(inputs, demographics)

        val_loss += criterion(outputs, labels.float()).item()
        probabilities = torch.sigmoid(outputs)
        predicted = (probabilities >= 0.5).int()

        correct += (predicted == labels).sum().item()
        total += labels.numel()

    avg_val_loss = val_loss / len(val_loader)
    val_accuracy = 100 * correct / total
    """writer.add_scalar("Loss/Validation", avg_val_loss, epoch)
    writer.add_scalar("Accuracy/Validation", val_accuracy, epoch)"""

    if val_accuracy > best_val_accuracy:
      best_val_accuracy = val_accuracy

    print(f"Epoch {epoch+1}/{num_epochs}, Training Loss: {avg_train_loss}, Validation Loss: {avg_val_loss}, Validation Accuracy: {val_accuracy}%")

  return best_val_accuracy

# %%
def evaluate_model(test_loader, model, criterion, precision_metric, recall_metric, f1_metric, confidence= 0.3):
    model.eval()
    correct = 0
    total = 0
    test_loss = 0.0

    precision_metric.reset()
    recall_metric.reset()
    f1_metric.reset()

    with torch.no_grad():
      for inputs, demographics, labels in test_loader:
        inputs, demographics, labels = inputs.to(device), demographics.to(device), labels.to(device)
        outputs = model(inputs, demographics)

        test_loss += criterion(outputs, labels.float()).item()

        probabilities = torch.sigmoid(outputs)
        predicted = (probabilities >= confidence).int()

        correct += (predicted == labels).sum().item()
        total += labels.numel()

        #print("predicted:", predicted)
        #print("labels: ", labels)

        precision_metric.update(predicted, labels)
        recall_metric.update(predicted, labels)
        f1_metric.update(predicted, labels)

    test_accuracy = 100 * correct / total
    precision = precision_metric.compute().item()
    recall = recall_metric.compute().item()
    f1_score = f1_metric.compute().item()
    avg_test_loss = test_loss / len(test_loader)

    """writer.add_scalar("Loss/Test", avg_test_loss)
    writer.add_scalar("Accuracy/Test", test_accuracy)
    writer.add_scalar("Precision/Test", precision)
    writer.add_scalar("Recall/Test", recall)
    writer.add_scalar("F1-Score/Test", f1_score)"""

    print(f'Test Loss: {avg_test_loss:.4f}')
    print(f'Test Accuracy: {test_accuracy:.2f}%')
    print(f'Test Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1_score:.4f}')

# %%
def objective(config):
    """num_epochs = trial.suggest_int("num_epochs", 5, 20)
    batch_size = trial.suggest_categorical("batch_size", [16, 32, 64])
    learning_rate = trial.suggest_loguniform("learning_rate", 1e-6, 1e-3)
    demographics_fc_size = trial.suggest_int("demographics_size", 32, 64, 128)"""

    num_epochs = config["num_epochs"]
    batch_size = config["batch_size"]
    learning_rate = config["learning_rate"]
    demographics_fc_size = config["demographics_fc_size"]

    train_loader, val_loader, test_loader = load_data(config["file_path"], batch_size, config["train_percent"], config["val_percent"])

    model = CustomResNet18(demographics_fc_size, num_demographics=config["num_demographics"], num_classes=config["num_classes"]).to(device)
    freeze_unfreeze_layers(model, freeze=True, layers_to_train=["layer4", "fc"])

    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.BCEWithLogitsLoss()

    best_val_accuracy_future = train_model.remote(train_loader, val_loader, model, criterion, optimizer, num_epochs)

    # Retrieve the result (best_val_accuracy) using ray.get()
    best_val_accuracy = ray.get(best_val_accuracy_future)

    #best_val_accuracy= ray.get(train_model(train_loader, val_loader, model, criterion, optimizer, num_epochs))

    tune.report(best_val_accuracy=best_val_accuracy)

# %%
num_samples= 10
#resources_per_trial = tune.PlacementGroupFactory([{'CPU': 1.0}]*num_samples)

analysis = tune.run(
    objective,
    config= config,
    resources_per_trial={"cpu": 1, "gpu": 0},
    num_samples= num_samples,
    metric="best_val_accuracy",
    mode="max"
)

best_trial = analysis.best_trial
print("Best trial:", best_trial)
# Out:
# +------------------------------------------------------------------+
# | Configuration for experiment     objective_2024-11-14_21-52-27   |
# +------------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator           |
# | Scheduler                        FIFOScheduler                   |
# | Number of trials                 10                              |
# +------------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/objective_2024-11-14_21-52-27
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts`
#
# Trial status: 10 PENDING
# Current time: 2024-11-14 21:52:27. Total running time: 0s
# Logical resource usage: 2.0/2 CPUs, 0/0 GPUs
# +-----------------------------------------------------------------------------------------------------------+
# | Trial name              status       num_epochs     batch_size     learning_rate     demographics_fc_size |
# +-----------------------------------------------------------------------------------------------------------+
# | objective_bd322_00000   PENDING               8             64       2.43862e-05                       64 |
# | objective_bd322_00001   PENDING               7             16       0.000621034                      128 |
# | objective_bd322_00002   PENDING              13             64       5.25482e-05                      128 |
# | objective_bd322_00003   PENDING              12             64       1.27334e-05                       64 |
# | objective_bd322_00004   PENDING              19             16       0.000194263                       64 |
# | objective_bd322_00005   PENDING              16             32       0.000865804                       32 |
# | objective_bd322_00006   PENDING              12             32       0.000411324                       64 |
# | objective_bd322_00007   PENDING               7             16       1.53666e-06                      128 |
# | objective_bd322_00008   PENDING              16             64       0.000395811                       32 |
# | objective_bd322_00009   PENDING              16             64       2.73746e-05                      128 |
# +-----------------------------------------------------------------------------------------------------------+
#
# Trial objective_bd322_00000 started with configuration:
# +-------------------------------------------------------------+
# | Trial objective_bd322_00000 config                          |
# +-------------------------------------------------------------+
# | batch_size                                               64 |
# | demographics_fc_size                                     64 |
# | file_path                              ...ed_dummy_data.pkl |
# | learning_rate                                       0.00002 |
# | num_classes                                              15 |
# | num_demographics                                          3 |
# | num_epochs                                                8 |
# | train_percent                                           0.7 |
# | val_percent                                             0.1 |
# +-------------------------------------------------------------+
# (objective pid=12679) Training samples: 35, Validation samples: 5, Test samples: 10
#
# Trial objective_bd322_00001 started with configuration:
# +-------------------------------------------------------------+
# | Trial objective_bd322_00001 config                          |
# +-------------------------------------------------------------+
# | batch_size                                               16 |
# | demographics_fc_size                                    128 |
# | file_path                              ...ed_dummy_data.pkl |
# | learning_rate                                       0.00062 |
# | num_classes                                              15 |
# | num_demographics                                          3 |
# | num_epochs                                                7 |
# | train_percent                                           0.7 |
# | val_percent                                             0.1 |
# +-------------------------------------------------------------+
# 2024-11-14 21:52:39,671	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_bd322_00000
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=12679, ip=172.28.0.12, actor_id=13de4702f5777b92b0c8510e01000000, repr=objective)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/_internal/util.py", line 104, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "<ipython-input-24-61796a6f0982>", line 20, in objective
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 139, in _remote_proxy
#     return self._remote(args=args, kwargs=kwargs, **self._default_options)
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 416, in _remote
#     _task_launch_hook(self._function_descriptor, resources, scheduling_strategy)
#   File "/usr/local/lib/python3.10/dist-packages/ray/train/_internal/session.py", line 557, in _tune_task_and_actor_launch_hook
#     raise RuntimeError(
# RuntimeError: No trial resources are available for launching the task `__main__.train_model`. To resolve this, specify the Tune option:
#
# >  resources_per_trial=tune.PlacementGroupFactory(
# >    [{'CPU': 1.0}] + [{'CPU': 1.0}] * N
# >  )
#
# Where `N` is the number of slots to reserve for trial tasks. If you are using a Ray training library, there might be a utility function to set this automatically for you. For more information, refer to https://docs.ray.io/en/latest/tune/tutorials/tune-resources.html
# 2024-11-14 21:52:39,757	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_bd322_00001
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=12678, ip=172.28.0.12, actor_id=b834cce00b7383add890699f01000000, repr=objective)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/_internal/util.py", line 104, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "<ipython-input-24-61796a6f0982>", line 20, in objective
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 139, in _remote_proxy
#     return self._remote(args=args, kwargs=kwargs, **self._default_options)
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 416, in _remote
#     _task_launch_hook(self._function_descriptor, resources, scheduling_strategy)
#   File "/usr/local/lib/python3.10/dist-packages/ray/train/_internal/session.py", line 557, in _tune_task_and_actor_launch_hook
#     raise RuntimeError(
# RuntimeError: No trial resources are available for launching the task `__main__.train_model`. To resolve this, specify the Tune option:
#
# >  resources_per_trial=tune.PlacementGroupFactory(
# >    [{'CPU': 1.0}] + [{'CPU': 1.0}] * N
# >  )
#
# Where `N` is the number of slots to reserve for trial tasks. If you are using a Ray training library, there might be a utility function to set this automatically for you. For more information, refer to https://docs.ray.io/en/latest/tune/tutorials/tune-resources.html
# Trial objective_bd322_00000 errored after 0 iterations at 2024-11-14 21:52:39. Total running time: 12s
# Error file: /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00000_0_batch_size=64,demographics_fc_size=64,learning_rate=0.0000,num_epochs=8_2024-11-14_21-52-27/error.txt
#
# Trial objective_bd322_00001 errored after 0 iterations at 2024-11-14 21:52:39. Total running time: 12s
# Error file: /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00001_1_batch_size=16,demographics_fc_size=128,learning_rate=0.0006,num_epochs=7_2024-11-14_21-52-27/error.txt
#
# Trial objective_bd322_00003 started with configuration:
# +-------------------------------------------------------------+
# | Trial objective_bd322_00003 config                          |
# +-------------------------------------------------------------+
# | batch_size                                               64 |
# | demographics_fc_size                                     64 |
# | file_path                              ...ed_dummy_data.pkl |
# | learning_rate                                       0.00001 |
# | num_classes                                              15 |
# | num_demographics                                          3 |
# | num_epochs                                               12 |
# | train_percent                                           0.7 |
# | val_percent                                             0.1 |
# +-------------------------------------------------------------+
# (objective pid=12875) Training samples: 35, Validation samples: 5, Test samples: 10 [repeated 2x across cluster]
#
# Trial objective_bd322_00002 started with configuration:
# +-------------------------------------------------------------+
# | Trial objective_bd322_00002 config                          |
# +-------------------------------------------------------------+
# | batch_size                                               64 |
# | demographics_fc_size                                    128 |
# | file_path                              ...ed_dummy_data.pkl |
# | learning_rate                                       0.00005 |
# | num_classes                                              15 |
# | num_demographics                                          3 |
# | num_epochs                                               13 |
# | train_percent                                           0.7 |
# | val_percent                                             0.1 |
# +-------------------------------------------------------------+
# 2024-11-14 21:52:53,290	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_bd322_00003
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=12875, ip=172.28.0.12, actor_id=39037210836f113174441f4001000000, repr=objective)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/_internal/util.py", line 104, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "<ipython-input-24-61796a6f0982>", line 20, in objective
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 139, in _remote_proxy
#     return self._remote(args=args, kwargs=kwargs, **self._default_options)
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 416, in _remote
#     _task_launch_hook(self._function_descriptor, resources, scheduling_strategy)
#   File "/usr/local/lib/python3.10/dist-packages/ray/train/_internal/session.py", line 557, in _tune_task_and_actor_launch_hook
#     raise RuntimeError(
# RuntimeError: No trial resources are available for launching the task `__main__.train_model`. To resolve this, specify the Tune option:
#
# >  resources_per_trial=tune.PlacementGroupFactory(
# >    [{'CPU': 1.0}] + [{'CPU': 1.0}] * N
# >  )
#
# Where `N` is the number of slots to reserve for trial tasks. If you are using a Ray training library, there might be a utility function to set this automatically for you. For more information, refer to https://docs.ray.io/en/latest/tune/tutorials/tune-resources.html
# Trial objective_bd322_00003 errored after 0 iterations at 2024-11-14 21:52:53. Total running time: 26s
# Error file: /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00003_3_batch_size=64,demographics_fc_size=64,learning_rate=0.0000,num_epochs=12_2024-11-14_21-52-27/error.txt
# 2024-11-14 21:52:53,583	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_bd322_00002
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=12874, ip=172.28.0.12, actor_id=1eee528dece87d49a068222a01000000, repr=objective)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/_internal/util.py", line 104, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "<ipython-input-24-61796a6f0982>", line 20, in objective
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 139, in _remote_proxy
#     return self._remote(args=args, kwargs=kwargs, **self._default_options)
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 416, in _remote
#     _task_launch_hook(self._function_descriptor, resources, scheduling_strategy)
#   File "/usr/local/lib/python3.10/dist-packages/ray/train/_internal/session.py", line 557, in _tune_task_and_actor_launch_hook
#     raise RuntimeError(
# RuntimeError: No trial resources are available for launching the task `__main__.train_model`. To resolve this, specify the Tune option:
#
# >  resources_per_trial=tune.PlacementGroupFactory(
# >    [{'CPU': 1.0}] + [{'CPU': 1.0}] * N
# >  )
#
# Where `N` is the number of slots to reserve for trial tasks. If you are using a Ray training library, there might be a utility function to set this automatically for you. For more information, refer to https://docs.ray.io/en/latest/tune/tutorials/tune-resources.html
# Trial objective_bd322_00002 errored after 0 iterations at 2024-11-14 21:52:53. Total running time: 26s
# Error file: /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00002_2_batch_size=64,demographics_fc_size=128,learning_rate=0.0001,num_epochs=13_2024-11-14_21-52-27/error.txt
#
# Trial status: 4 ERROR | 6 PENDING
# Current time: 2024-11-14 21:52:57. Total running time: 30s
# Logical resource usage: 2.0/2 CPUs, 0/0 GPUs
# +-----------------------------------------------------------------------------------------------------------+
# | Trial name              status       num_epochs     batch_size     learning_rate     demographics_fc_size |
# +-----------------------------------------------------------------------------------------------------------+
# | objective_bd322_00004   PENDING              19             16       0.000194263                       64 |
# | objective_bd322_00005   PENDING              16             32       0.000865804                       32 |
# | objective_bd322_00006   PENDING              12             32       0.000411324                       64 |
# | objective_bd322_00007   PENDING               7             16       1.53666e-06                      128 |
# | objective_bd322_00008   PENDING              16             64       0.000395811                       32 |
# | objective_bd322_00009   PENDING              16             64       2.73746e-05                      128 |
# | objective_bd322_00000   ERROR                 8             64       2.43862e-05                       64 |
# | objective_bd322_00001   ERROR                 7             16       0.000621034                      128 |
# | objective_bd322_00002   ERROR                13             64       5.25482e-05                      128 |
# | objective_bd322_00003   ERROR                12             64       1.27334e-05                       64 |
# +-----------------------------------------------------------------------------------------------------------+
#
# Trial objective_bd322_00004 started with configuration:
# +-------------------------------------------------------------+
# | Trial objective_bd322_00004 config                          |
# +-------------------------------------------------------------+
# | batch_size                                               16 |
# | demographics_fc_size                                     64 |
# | file_path                              ...ed_dummy_data.pkl |
# | learning_rate                                       0.00019 |
# | num_classes                                              15 |
# | num_demographics                                          3 |
# | num_epochs                                               19 |
# | train_percent                                           0.7 |
# | val_percent                                             0.1 |
# +-------------------------------------------------------------+
# (objective pid=13034) Training samples: 35, Validation samples: 5, Test samples: 10 [repeated 2x across cluster]
# 2024-11-14 21:53:06,450	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_bd322_00004
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=13034, ip=172.28.0.12, actor_id=8ca1c10c2d49816da14d833801000000, repr=objective)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/_internal/util.py", line 104, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "<ipython-input-24-61796a6f0982>", line 20, in objective
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 139, in _remote_proxy
#     return self._remote(args=args, kwargs=kwargs, **self._default_options)
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 416, in _remote
#     _task_launch_hook(self._function_descriptor, resources, scheduling_strategy)
#   File "/usr/local/lib/python3.10/dist-packages/ray/train/_internal/session.py", line 557, in _tune_task_and_actor_launch_hook
#     raise RuntimeError(
# RuntimeError: No trial resources are available for launching the task `__main__.train_model`. To resolve this, specify the Tune option:
#
# >  resources_per_trial=tune.PlacementGroupFactory(
# >    [{'CPU': 1.0}] + [{'CPU': 1.0}] * N
# >  )
#
# Where `N` is the number of slots to reserve for trial tasks. If you are using a Ray training library, there might be a utility function to set this automatically for you. For more information, refer to https://docs.ray.io/en/latest/tune/tutorials/tune-resources.html
# Trial objective_bd322_00004 errored after 0 iterations at 2024-11-14 21:53:06. Total running time: 39s
# Error file: /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00004_4_batch_size=16,demographics_fc_size=64,learning_rate=0.0002,num_epochs=19_2024-11-14_21-52-27/error.txt
#
# Trial objective_bd322_00005 started with configuration:
# +-------------------------------------------------------------+
# | Trial objective_bd322_00005 config                          |
# +-------------------------------------------------------------+
# | batch_size                                               32 |
# | demographics_fc_size                                     32 |
# | file_path                              ...ed_dummy_data.pkl |
# | learning_rate                                       0.00087 |
# | num_classes                                              15 |
# | num_demographics                                          3 |
# | num_epochs                                               16 |
# | train_percent                                           0.7 |
# | val_percent                                             0.1 |
# +-------------------------------------------------------------+
# 2024-11-14 21:53:07,199	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_bd322_00005
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=13042, ip=172.28.0.12, actor_id=309ce6384b041c817df47b7f01000000, repr=objective)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/_internal/util.py", line 104, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "<ipython-input-24-61796a6f0982>", line 20, in objective
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 139, in _remote_proxy
#     return self._remote(args=args, kwargs=kwargs, **self._default_options)
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 416, in _remote
#     _task_launch_hook(self._function_descriptor, resources, scheduling_strategy)
#   File "/usr/local/lib/python3.10/dist-packages/ray/train/_internal/session.py", line 557, in _tune_task_and_actor_launch_hook
#     raise RuntimeError(
# RuntimeError: No trial resources are available for launching the task `__main__.train_model`. To resolve this, specify the Tune option:
#
# >  resources_per_trial=tune.PlacementGroupFactory(
# >    [{'CPU': 1.0}] + [{'CPU': 1.0}] * N
# >  )
#
# Where `N` is the number of slots to reserve for trial tasks. If you are using a Ray training library, there might be a utility function to set this automatically for you. For more information, refer to https://docs.ray.io/en/latest/tune/tutorials/tune-resources.html
# Trial objective_bd322_00005 errored after 0 iterations at 2024-11-14 21:53:07. Total running time: 39s
# Error file: /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00005_5_batch_size=32,demographics_fc_size=32,learning_rate=0.0009,num_epochs=16_2024-11-14_21-52-27/error.txt
#
# Trial objective_bd322_00006 started with configuration:
# +-------------------------------------------------------------+
# | Trial objective_bd322_00006 config                          |
# +-------------------------------------------------------------+
# | batch_size                                               32 |
# | demographics_fc_size                                     64 |
# | file_path                              ...ed_dummy_data.pkl |
# | learning_rate                                       0.00041 |
# | num_classes                                              15 |
# | num_demographics                                          3 |
# | num_epochs                                               12 |
# | train_percent                                           0.7 |
# | val_percent                                             0.1 |
# +-------------------------------------------------------------+
# (objective pid=13229) Training samples: 35, Validation samples: 5, Test samples: 10 [repeated 2x across cluster]
#
# Trial objective_bd322_00007 started with configuration:
# +-------------------------------------------------------------+
# | Trial objective_bd322_00007 config                          |
# +-------------------------------------------------------------+
# | batch_size                                               16 |
# | demographics_fc_size                                    128 |
# | file_path                              ...ed_dummy_data.pkl |
# | learning_rate                                            0. |
# | num_classes                                              15 |
# | num_demographics                                          3 |
# | num_epochs                                                7 |
# | train_percent                                           0.7 |
# | val_percent                                             0.1 |
# +-------------------------------------------------------------+
# 2024-11-14 21:53:21,673	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_bd322_00006
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=13229, ip=172.28.0.12, actor_id=b03468f2e19291f81ac41e4b01000000, repr=objective)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/_internal/util.py", line 104, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "<ipython-input-24-61796a6f0982>", line 20, in objective
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 139, in _remote_proxy
#     return self._remote(args=args, kwargs=kwargs, **self._default_options)
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 416, in _remote
#     _task_launch_hook(self._function_descriptor, resources, scheduling_strategy)
#   File "/usr/local/lib/python3.10/dist-packages/ray/train/_internal/session.py", line 557, in _tune_task_and_actor_launch_hook
#     raise RuntimeError(
# RuntimeError: No trial resources are available for launching the task `__main__.train_model`. To resolve this, specify the Tune option:
#
# >  resources_per_trial=tune.PlacementGroupFactory(
# >    [{'CPU': 1.0}] + [{'CPU': 1.0}] * N
# >  )
#
# Where `N` is the number of slots to reserve for trial tasks. If you are using a Ray training library, there might be a utility function to set this automatically for you. For more information, refer to https://docs.ray.io/en/latest/tune/tutorials/tune-resources.html
# 2024-11-14 21:53:21,707	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_bd322_00007
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=13231, ip=172.28.0.12, actor_id=333ceeae58fa538b53c4843f01000000, repr=objective)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/_internal/util.py", line 104, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "<ipython-input-24-61796a6f0982>", line 20, in objective
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 139, in _remote_proxy
#     return self._remote(args=args, kwargs=kwargs, **self._default_options)
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 416, in _remote
#     _task_launch_hook(self._function_descriptor, resources, scheduling_strategy)
#   File "/usr/local/lib/python3.10/dist-packages/ray/train/_internal/session.py", line 557, in _tune_task_and_actor_launch_hook
#     raise RuntimeError(
# RuntimeError: No trial resources are available for launching the task `__main__.train_model`. To resolve this, specify the Tune option:
#
# >  resources_per_trial=tune.PlacementGroupFactory(
# >    [{'CPU': 1.0}] + [{'CPU': 1.0}] * N
# >  )
#
# Where `N` is the number of slots to reserve for trial tasks. If you are using a Ray training library, there might be a utility function to set this automatically for you. For more information, refer to https://docs.ray.io/en/latest/tune/tutorials/tune-resources.html
# Trial objective_bd322_00006 errored after 0 iterations at 2024-11-14 21:53:21. Total running time: 54s
# Error file: /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00006_6_batch_size=32,demographics_fc_size=64,learning_rate=0.0004,num_epochs=12_2024-11-14_21-52-27/error.txt
#
# Trial objective_bd322_00007 errored after 0 iterations at 2024-11-14 21:53:21. Total running time: 54s
# Error file: /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00007_7_batch_size=16,demographics_fc_size=128,learning_rate=0.0000,num_epochs=7_2024-11-14_21-52-27/error.txt
#
# Trial status: 8 ERROR | 2 PENDING
# Current time: 2024-11-14 21:53:27. Total running time: 1min 0s
# Logical resource usage: 2.0/2 CPUs, 0/0 GPUs
# +-----------------------------------------------------------------------------------------------------------+
# | Trial name              status       num_epochs     batch_size     learning_rate     demographics_fc_size |
# +-----------------------------------------------------------------------------------------------------------+
# | objective_bd322_00008   PENDING              16             64       0.000395811                       32 |
# | objective_bd322_00009   PENDING              16             64       2.73746e-05                      128 |
# | objective_bd322_00000   ERROR                 8             64       2.43862e-05                       64 |
# | objective_bd322_00001   ERROR                 7             16       0.000621034                      128 |
# | objective_bd322_00002   ERROR                13             64       5.25482e-05                      128 |
# | objective_bd322_00003   ERROR                12             64       1.27334e-05                       64 |
# | objective_bd322_00004   ERROR                19             16       0.000194263                       64 |
# | objective_bd322_00005   ERROR                16             32       0.000865804                       32 |
# | objective_bd322_00006   ERROR                12             32       0.000411324                       64 |
# | objective_bd322_00007   ERROR                 7             16       1.53666e-06                      128 |
# +-----------------------------------------------------------------------------------------------------------+
#
# Trial objective_bd322_00009 started with configuration:
# +-------------------------------------------------------------+
# | Trial objective_bd322_00009 config                          |
# +-------------------------------------------------------------+
# | batch_size                                               64 |
# | demographics_fc_size                                    128 |
# | file_path                              ...ed_dummy_data.pkl |
# | learning_rate                                       0.00003 |
# | num_classes                                              15 |
# | num_demographics                                          3 |
# | num_epochs                                               16 |
# | train_percent                                           0.7 |
# | val_percent                                             0.1 |
# +-------------------------------------------------------------+
#
# Trial objective_bd322_00008 started with configuration:
# +-------------------------------------------------------------+
# | Trial objective_bd322_00008 config                          |
# +-------------------------------------------------------------+
# | batch_size                                               64 |
# | demographics_fc_size                                     32 |
# | file_path                              ...ed_dummy_data.pkl |
# | learning_rate                                        0.0004 |
# | num_classes                                              15 |
# | num_demographics                                          3 |
# | num_epochs                                               16 |
# | train_percent                                           0.7 |
# | val_percent                                             0.1 |
# +-------------------------------------------------------------+
# (objective pid=13430) Training samples: 35, Validation samples: 5, Test samples: 10 [repeated 2x across cluster]
# 2024-11-14 21:53:35,401	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_bd322_00009
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=13430, ip=172.28.0.12, actor_id=59d1bf2c1f8b3d20fa8bf7b001000000, repr=objective)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/_internal/util.py", line 104, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "<ipython-input-24-61796a6f0982>", line 20, in objective
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 139, in _remote_proxy
#     return self._remote(args=args, kwargs=kwargs, **self._default_options)
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 416, in _remote
#     _task_launch_hook(self._function_descriptor, resources, scheduling_strategy)
#   File "/usr/local/lib/python3.10/dist-packages/ray/train/_internal/session.py", line 557, in _tune_task_and_actor_launch_hook
#     raise RuntimeError(
# RuntimeError: No trial resources are available for launching the task `__main__.train_model`. To resolve this, specify the Tune option:
#
# >  resources_per_trial=tune.PlacementGroupFactory(
# >    [{'CPU': 1.0}] + [{'CPU': 1.0}] * N
# >  )
#
# Where `N` is the number of slots to reserve for trial tasks. If you are using a Ray training library, there might be a utility function to set this automatically for you. For more information, refer to https://docs.ray.io/en/latest/tune/tutorials/tune-resources.html
# 2024-11-14 21:53:35,481	ERROR tune_controller.py:1331 -- Trial task failed for trial objective_bd322_00008
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/usr/local/lib/python3.10/dist-packages/ray/_private/worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(RuntimeError): ray::ImplicitFunc.train() (pid=13428, ip=172.28.0.12, actor_id=08355e63d9c9b0211ebef23d01000000, repr=objective)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/trainable.py", line 331, in train
#     raise skipped from exception_cause(skipped)
#   File "/usr/local/lib/python3.10/dist-packages/ray/air/_internal/util.py", line 104, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 45, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#   File "/usr/local/lib/python3.10/dist-packages/ray/tune/trainable/function_trainable.py", line 250, in _trainable_func
#     output = fn()
#   File "<ipython-input-24-61796a6f0982>", line 20, in objective
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 139, in _remote_proxy
#     return self._remote(args=args, kwargs=kwargs, **self._default_options)
#   File "/usr/local/lib/python3.10/dist-packages/ray/remote_function.py", line 416, in _remote
#     _task_launch_hook(self._function_descriptor, resources, scheduling_strategy)
#   File "/usr/local/lib/python3.10/dist-packages/ray/train/_internal/session.py", line 557, in _tune_task_and_actor_launch_hook
#     raise RuntimeError(
# RuntimeError: No trial resources are available for launching the task `__main__.train_model`. To resolve this, specify the Tune option:
#
# >  resources_per_trial=tune.PlacementGroupFactory(
# >    [{'CPU': 1.0}] + [{'CPU': 1.0}] * N
# >  )
#
# Where `N` is the number of slots to reserve for trial tasks. If you are using a Ray training library, there might be a utility function to set this automatically for you. For more information, refer to https://docs.ray.io/en/latest/tune/tutorials/tune-resources.html
# 2024-11-14 21:53:35,511	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/objective_2024-11-14_21-52-27' in 0.0206s.
# Trial objective_bd322_00009 errored after 0 iterations at 2024-11-14 21:53:35. Total running time: 1min 8s
# Error file: /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00009_9_batch_size=64,demographics_fc_size=128,learning_rate=0.0000,num_epochs=16_2024-11-14_21-52-27/error.txt
#
# Trial objective_bd322_00008 errored after 0 iterations at 2024-11-14 21:53:35. Total running time: 1min 8s
# Error file: /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00008_8_batch_size=64,demographics_fc_size=32,learning_rate=0.0004,num_epochs=16_2024-11-14_21-52-27/error.txt
#
# Trial status: 10 ERROR
# Current time: 2024-11-14 21:53:35. Total running time: 1min 8s
# Logical resource usage: 1.0/2 CPUs, 0/0 GPUs
# +-----------------------------------------------------------------------------------------------------------+
# | Trial name              status       num_epochs     batch_size     learning_rate     demographics_fc_size |
# +-----------------------------------------------------------------------------------------------------------+
# | objective_bd322_00000   ERROR                 8             64       2.43862e-05                       64 |
# | objective_bd322_00001   ERROR                 7             16       0.000621034                      128 |
# | objective_bd322_00002   ERROR                13             64       5.25482e-05                      128 |
# | objective_bd322_00003   ERROR                12             64       1.27334e-05                       64 |
# | objective_bd322_00004   ERROR                19             16       0.000194263                       64 |
# | objective_bd322_00005   ERROR                16             32       0.000865804                       32 |
# | objective_bd322_00006   ERROR                12             32       0.000411324                       64 |
# | objective_bd322_00007   ERROR                 7             16       1.53666e-06                      128 |
# | objective_bd322_00008   ERROR                16             64       0.000395811                       32 |
# | objective_bd322_00009   ERROR                16             64       2.73746e-05                      128 |
# +-----------------------------------------------------------------------------------------------------------+
#
# Number of errored trials: 10
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                # failures   error file                                                                                                                                                                                                                                                    |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | objective_bd322_00000              1   /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00000_0_batch_size=64,demographics_fc_size=64,learning_rate=0.0000,num_epochs=8_2024-11-14_21-52-27/error.txt   |
# | objective_bd322_00001              1   /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00001_1_batch_size=16,demographics_fc_size=128,learning_rate=0.0006,num_epochs=7_2024-11-14_21-52-27/error.txt  |
# | objective_bd322_00002              1   /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00002_2_batch_size=64,demographics_fc_size=128,learning_rate=0.0001,num_epochs=13_2024-11-14_21-52-27/error.txt |
# | objective_bd322_00003              1   /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00003_3_batch_size=64,demographics_fc_size=64,learning_rate=0.0000,num_epochs=12_2024-11-14_21-52-27/error.txt  |
# | objective_bd322_00004              1   /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00004_4_batch_size=16,demographics_fc_size=64,learning_rate=0.0002,num_epochs=19_2024-11-14_21-52-27/error.txt  |
# | objective_bd322_00005              1   /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00005_5_batch_size=32,demographics_fc_size=32,learning_rate=0.0009,num_epochs=16_2024-11-14_21-52-27/error.txt  |
# | objective_bd322_00006              1   /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00006_6_batch_size=32,demographics_fc_size=64,learning_rate=0.0004,num_epochs=12_2024-11-14_21-52-27/error.txt  |
# | objective_bd322_00007              1   /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00007_7_batch_size=16,demographics_fc_size=128,learning_rate=0.0000,num_epochs=7_2024-11-14_21-52-27/error.txt  |
# | objective_bd322_00008              1   /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00008_8_batch_size=64,demographics_fc_size=32,learning_rate=0.0004,num_epochs=16_2024-11-14_21-52-27/error.txt  |
# | objective_bd322_00009              1   /tmp/ray/session_2024-11-14_21-51-56_342513_5340/artifacts/2024-11-14_21-52-27/objective_2024-11-14_21-52-27/driver_artifacts/objective_bd322_00009_9_batch_size=64,demographics_fc_size=128,learning_rate=0.0000,num_epochs=16_2024-11-14_21-52-27/error.txt |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ---------------------------------------------------------------------------
# TuneError                                 Traceback (most recent call last)
# <ipython-input-25-c043ec5c9d48> in <cell line: 4>()
#       2 resources_per_trial = tune.PlacementGroupFactory([{'CPU': 1.0}]*num_samples)
#       3
# ----> 4 analysis = tune.run(
#       5     objective,
#       6     config= config,
#
# /usr/local/lib/python3.10/dist-packages/ray/tune/tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, storage_path, storage_filesystem, search_alg, scheduler, checkpoint_config, verbose, progress_reporter, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, resume, resume_config, reuse_actors, raise_on_failed_trial, callbacks, max_concurrent_trials, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, chdir_to_trial_dir, local_dir, _remote, _remote_string_queue, _entrypoint)
#    1033     if incomplete_trials:
#    1034         if raise_on_failed_trial and not experiment_interrupted_event.is_set():
# -> 1035             raise TuneError("Trials did not complete", incomplete_trials)
#    1036         else:
#    1037             logger.error("Trials did not complete: %s", incomplete_trials)
#
# TuneError: ('Trials did not complete', [objective_bd322_00000, objective_bd322_00001, objective_bd322_00002, objective_bd322_00003, objective_bd322_00004, objective_bd322_00005, objective_bd322_00006, objective_bd322_00007, objective_bd322_00008, objective_bd322_00009])
